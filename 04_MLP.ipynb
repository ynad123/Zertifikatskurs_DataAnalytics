# %% [markdown]
# # Übung MultiLayerPerceptron
#
# Dieses Beispiel bezieht sich auf das Buch "Deep Learning with Python" Abschnitt 7, das Sie unter folgendem link finden:
#
# https://github.com/ynad123/Zertifikatskurs_DataAnalytics/blob/master/books/deep_learning_with_python.pdf
#
#
# Arbeiten Sie den Abschnitt im Buch durch und kommentieren Sie in diesem Notebook die einzelnen Zellen, so dass Sie jeden einzelnen Schritt erklären und nachvollziehen können.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Sequential

# %%
df = pd.read_csv('./data/pima-indians-diabetes.csv')
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
print(X.shape)
print('--')
print(Y.shape)
# Out:
# (767, 8)
# --
# (767,)

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X,Y,epochs=150, batch_size=10)
# Out:
# Train on 767 samples
# Epoch 1/150
# 767/767 [==============================] - 1s 1ms/sample - loss: 4.5860 - accuracy: 0.5150
# Epoch 2/150
# 767/767 [==============================] - 0s 301us/sample - loss: 2.3039 - accuracy: 0.5046
# Epoch 3/150
# 767/767 [==============================] - 0s 327us/sample - loss: 1.1878 - accuracy: 0.5528
# Epoch 4/150
# 767/767 [==============================] - 0s 293us/sample - loss: 0.8788 - accuracy: 0.5984
# Epoch 5/150
# 767/767 [==============================] - 0s 293us/sample - loss: 0.7972 - accuracy: 0.6454
# Epoch 6/150
# 767/767 [==============================] - 0s 303us/sample - loss: 0.7425 - accuracy: 0.6389
# Epoch 7/150
# 767/767 [==============================] - 0s 283us/sample - loss: 0.7127 - accuracy: 0.6467
# Epoch 8/150
# 767/767 [==============================] - 0s 350us/sample - loss: 0.7008 - accuracy: 0.6454
# Epoch 9/150
# ...

# %%
#Plot für Diagramm
num_epochs = np.arange(0, 150)
#plt.figure(dpi=600)
plt.plot(num_epochs, history.history['loss'], label='train_loss', c='blue')
plt.title('Wert der Verlustfunktion')
plt.xlabel('Epochen')
plt.ylabel('Genauigkeit bzw. Verlust')
plt.legend()
plt.grid()
plt.savefig('Diagramm.png')

# %%
scores = model.evaluate(X,Y)
# Out:
# 767/767 [==============================] - 0s 218us/sample - loss: 0.6493 - accuracy: 0.6988
